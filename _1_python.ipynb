# %% [markdown]
# <a href="https://colab.research.google.com/github/visotin34512-ai/-1/blob/main/_1_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = input()
if len(word) % 2 == 0:
    mid_word = word[int(len(word) / 2 -1): int(len(word) / 2 + 1)]
else:
    mid_word = word[round((len(word)-1) / 2)]

mid_word
# Out:
# test
# 'es'

# %%
boys = sorted(['Peter', 'Alex', 'John', 'Arthur', 'Richard'])
girls = sorted(['Kate', 'Liza', 'Kira', 'Emma', 'Trisha'])

if len(boys) == len(girls):
    print("Идеальные пары:")
    [print(f"{boys[x]} и {girls[x]}") for x in range(len(boys))]
else:
    print("Внимание, кто-то может остаться без пары!")
# Out:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha
